# %% [markdown]
# # University Speech Analysis
#
# By Guo (Jerry) Cheng, September 2024

# %%
import pandas as pd

# %%
# Load the raw data
univ_speech = pd.read_csv("../data/university-speech.csv",
                          encoding = "utf-8-sig")

# Show head
univ_speech.head()
# Out:
#   published_date   speech_type src_type       src_id  \
# 0   May 23, 2024  commencement    video  7dETo7ECQKc
# 1   May 23, 2024  commencement    video  Ap6PqQ9wPYA
# 2   May 26, 2023  commencement    video  dkPo5nfEk1w
# 3   May 26, 2023  commencement    video  XrRFYrv7TbA
# 4   May 26, 2023  commencement    video  3C95a-lQbRY
#
#                                                title  \
# 0  Maria Ressa delivers the Commencement Address ...
# 1  Shruthi Kumar delivers her senior English addr...
# 2  Tom Hanks delivers the Commencement Address | ...
# 3  Vic Hogg delivers the Graduate English Address...
# 4  Pallas Chou delivers the Senior English Addres...
#
#                                                 desc        channel_name  \
# 0  On May 23, 2024, Maria Ressa, a recipient of t...  Harvard University
# 1  A masterful oration by Shruthi Kumar.         ...                 Wil
# 2  On May 25, 2023, actor Tom Hanks addressed the...  Harvard University
# ...
